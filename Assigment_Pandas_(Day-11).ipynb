# %% [markdown]
# > # <span style="color:blue"> ***Participant***
# > Title= "Mr."\
# > Nmae= Naseer Muhammad Khan\
# > email= "engrnaseer1@gmail.com"\
# > Whatsapp= "00923469198690"" </span>

# %% [markdown]
# # <span style="color:green"> <p align="center"> **Pandas Assignment**

# %% [markdown]
# #### <span style="color:yellow"> <p align="center"> *Libraries installation* (pandas, numpy)
# </span>
# </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### <span style="color:blue"> <p align="center"> import csv file

# %%
data=pd.read_csv("faostat_data_1-12-2022.csv")
data
# Out:
#    Domain Code             Domain  Area Code      Area  Element Code  \
# 0           OA  Annual population        165  Pakistan           551
# 1           OA  Annual population        165  Pakistan           561
# 2           OA  Annual population        165  Pakistan           561
# 3           OA  Annual population        165  Pakistan           551
# 4           OA  Annual population        165  Pakistan           551
# 5           OA  Annual population        165  Pakistan           561
# 6           OA  Annual population        165  Pakistan           561
# 7           OA  Annual population        165  Pakistan           551
# 8           OA  Annual population        165  Pakistan           551
# 9           OA  Annual population        165  Pakistan           561
# 10          OA  Annual population        165  Pakistan           561
# 11          OA  Annual population        165  Pakistan           551
# 12          OA  Annual population        165  Pakistan           551
# ...

# %% [markdown]
# ##### <span style="color:blue"> <p align="center"> to see the first to rows of the data

# %%
data.head(2)
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 0          OA  Annual population        165  Pakistan           551
# 1          OA  Annual population        165  Pakistan           561
#
#             Element  Item Code                       Item  Year Code  Year  \
# 0  Rural population       3010  Population - Est. & Proj.       1990  1990
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
#
#            Unit      Value Flag                Flag Description  \
# 0  1000 persons  74754.921    X  International reliable sources
# 1  1000 persons  32923.693    X  International reliable sources
#
#                                                 Note
# 0                                                NaN
# 1  UNDESA, Population Division ? World Urbanizati...

# %% [markdown]
# ##### <span style="color:blue"> <p align="center"> to see the lasst to rows of the data

# %%
data.tail(2)
# Out:
#    Domain Code             Domain  Area Code      Area  Element Code  \
# 56          OA  Annual population        165  Pakistan           551
# 57          OA  Annual population        165  Pakistan           561
#
#              Element  Item Code                       Item  Year Code  Year  \
# 56  Rural population       3010  Population - Est. & Proj.       2018  2018
# 57  Urban population       3010  Population - Est. & Proj.       2018  2018
#
#             Unit       Value Flag                Flag Description  \
# 56  1000 persons  127183.388    X  International reliable sources
# 57  1000 persons   73630.430    X  International reliable sources
#
#                                                  Note
# 56                                                NaN
# 57  UNDESA, Population Division ? World Urbanizati...

# %%
data.dtypes
# Out:
# Domain Code          object
# Domain               object
# Area Code             int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code             int64
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# Note                 object
# dtype: object

# %%
data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Flag Description', 'Note'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=58, step=1)

# %%
data.to_numpy()
# Out:
# array([['OA', 'Annual population', 165, 'Pakistan', 551,
#         'Rural population', 3010, 'Population - Est. & Proj.', 1990,
#         1990, '1000 persons', 74754.921, 'X',
#         'International reliable sources', nan],
#        ['OA', 'Annual population', 165, 'Pakistan', 561,
#         'Urban population', 3010, 'Population - Est. & Proj.', 1990,
#         1990, '1000 persons', 32923.693, 'X',
#         'International reliable sources',
#         'UNDESA, Population Division ? World Urbanization Prospects, the 2018 Revision'],
#        ['OA', 'Annual population', 165, 'Pakistan', 561,
#         'Urban population', 3010, 'Population - Est. & Proj.', 1991,
#         1991, '1000 persons', 34133.44, 'X',
#         'International reliable sources',
#         'UNDESA, Population Division ? World Urbanization Prospects, the 2018 Revision'],
#        ['OA', 'Annual population', 165, 'Pakistan', 551,
#         'Rural population', 3010, 'Population - Est. & Proj.', 1991,
# ...

# %%
data.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count       58.0     58.000000       58.0    58.000000    58.000000
# mean       165.0    556.000000     3010.0  2004.000000  2004.000000
# std          0.0      5.043669        0.0     8.439672     8.439672
# min        165.0    551.000000     3010.0  1990.000000  1990.000000
# 25%        165.0    551.000000     3010.0  1997.000000  1997.000000
# 50%        165.0    556.000000     3010.0  2004.000000  2004.000000
# 75%        165.0    561.000000     3010.0  2011.000000  2011.000000
# max        165.0    561.000000     3010.0  2018.000000  2018.000000
#
#                Value
# count      58.000000
# mean    76031.216966
# std     28181.561500
# min     32923.693000
# 25%     51276.889250
# 50%     74192.675500
# 75%     99409.902500
# max    127183.388000

# %%
data.empty
# Out:
# False

# %%
data.equals
# Out:
# <bound method NDFrame.equals of    Domain Code             Domain  Area Code      Area  Element Code  \
# 0           OA  Annual population        165  Pakistan           551
# 1           OA  Annual population        165  Pakistan           561
# 2           OA  Annual population        165  Pakistan           561
# 3           OA  Annual population        165  Pakistan           551
# 4           OA  Annual population        165  Pakistan           551
# 5           OA  Annual population        165  Pakistan           561
# 6           OA  Annual population        165  Pakistan           561
# 7           OA  Annual population        165  Pakistan           551
# 8           OA  Annual population        165  Pakistan           551
# 9           OA  Annual population        165  Pakistan           561
# 10          OA  Annual population        165  Pakistan           561
# 11          OA  Annual population        165  Pakistan           551
# ...

# %%
data["Element Code"]
# Out:
# 0     551
# 1     561
# 2     561
# 3     551
# 4     551
# 5     561
# 6     561
# 7     551
# 8     551
# 9     561
# 10    561
# 11    551
# 12    551
# 13    561
# 14    561
# 15    551
# 16    551
# 17    561
# 18    561
# 19    551
# 20    551
# 21    561
# 22    561
# 23    551
# 24    551
# 25    561
# 26    561
# 27    551
# 28    551
# 29    561
# 30    561
# 31    551
# 32    551
# 33    561
# 34    561
# 35    551
# 36    551
# 37    561
# 38    561
# 39    551
# 40    551
# 41    561
# 42    561
# 43    551
# 44    551
# 45    561
# 46    561
# 47    551
# 48    551
# 49    561
# 50    561
# 51    551
# 52    551
# 53    561
# 54    561
# 55    551
# 56    551
# 57    561
# Name: Element Code, dtype: int64

# %%
data[0:5]
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 0          OA  Annual population        165  Pakistan           551
# 1          OA  Annual population        165  Pakistan           561
# 2          OA  Annual population        165  Pakistan           561
# 3          OA  Annual population        165  Pakistan           551
# 4          OA  Annual population        165  Pakistan           551
#
#             Element  Item Code                       Item  Year Code  Year  \
# 0  Rural population       3010  Population - Est. & Proj.       1990  1990
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
# 2  Urban population       3010  Population - Est. & Proj.       1991  1991
# 3  Rural population       3010  Population - Est. & Proj.       1991  1991
# 4  Rural population       3010  Population - Est. & Proj.       1992  1992
#
#            Unit      Value Flag                Flag Description  \
# ...

# %%
data. iloc[:,1:3]
# Out:
#                Domain  Area Code
# 0   Annual population        165
# 1   Annual population        165
# 2   Annual population        165
# 3   Annual population        165
# 4   Annual population        165
# 5   Annual population        165
# 6   Annual population        165
# 7   Annual population        165
# 8   Annual population        165
# 9   Annual population        165
# 10  Annual population        165
# 11  Annual population        165
# 12  Annual population        165
# 13  Annual population        165
# 14  Annual population        165
# 15  Annual population        165
# 16  Annual population        165
# 17  Annual population        165
# 18  Annual population        165
# 19  Annual population        165
# 20  Annual population        165
# 21  Annual population        165
# 22  Annual population        165
# 23  Annual population        165
# 24  Annual population        165
# 25  Annual population        165
# 26  Annual population        165
# ...

# %%
data.iloc[1:3,:]
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 1          OA  Annual population        165  Pakistan           561
# 2          OA  Annual population        165  Pakistan           561
#
#             Element  Item Code                       Item  Year Code  Year  \
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
# 2  Urban population       3010  Population - Est. & Proj.       1991  1991
#
#            Unit      Value Flag                Flag Description  \
# 1  1000 persons  32923.693    X  International reliable sources
# 2  1000 persons  34133.440    X  International reliable sources
#
#                                                 Note
# 1  UNDESA, Population Division ? World Urbanizati...
# 2  UNDESA, Population Division ? World Urbanizati...

# %%
data.mean
# Out:
# <bound method DataFrame.mean of    Domain Code             Domain  Area Code      Area  Element Code  \
# 0           OA  Annual population        165  Pakistan           551
# 1           OA  Annual population        165  Pakistan           561
# 2           OA  Annual population        165  Pakistan           561
# 3           OA  Annual population        165  Pakistan           551
# 4           OA  Annual population        165  Pakistan           551
# 5           OA  Annual population        165  Pakistan           561
# 6           OA  Annual population        165  Pakistan           561
# 7           OA  Annual population        165  Pakistan           551
# 8           OA  Annual population        165  Pakistan           551
# 9           OA  Annual population        165  Pakistan           561
# 10          OA  Annual population        165  Pakistan           561
# 11          OA  Annual population        165  Pakistan           551
# ...

# %%
data.mean(0)
# Out:
# Area Code         165.000000
# Element Code      556.000000
# Item Code        3010.000000
# Year Code        2004.000000
# Year             2004.000000
# Value           76031.216966
# dtype: float64

# %% [markdown]
# >>>## <span style="color:green"> <p align="center"> ***Plotting***

# %%
import seaborn as sns
#data.plot.bar(x="Year", y= "Value", figsize=(10,5));
sns.countplot(data=data);

# %%
import seaborn as sns
sns.barplot(x="Year",y="Element", hue= "Item", data=data);

# %%
import seaborn as sns
sns.barplot(x="Year",y="Element", hue= "Item", data=data, palette="rocket", saturation=0.5);
